# %%
f=open("saveTT.txt", "a+",encoding='utf-8')

for status in tweepy.Cursor(api.home_timeline).items(3):
    print(status._json)
    f.write(str(status._json))
    
f.close()
# Out:
# {'created_at': 'Tue Feb 26 07:53:02 +0000 2019', 'id': 1100302707875753984, 'id_str': '1100302707875753984', 'text': 'เตรียมสาดกระสุน! The Division 2 เผยรายละเอียดช่วงเปิดทดสอบ Open Beta - https://t.co/z0Bs4cPmxG https://t.co/krrmzwobDK', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/z0Bs4cPmxG', 'expanded_url': 'https://www.beartai.com/news/game-news/311906', 'display_url': 'beartai.com/news/game-news…', 'indices': [71, 94]}], 'media': [{'id': 1100302705833127936, 'id_str': '1100302705833127936', 'indices': [95, 118], 'media_url': 'http://pbs.twimg.com/media/D0UPezaVsAA3pBm.jpg', 'media_url_https': 'https://pbs.twimg.com/media/D0UPezaVsAA3pBm.jpg', 'url': 'https://t.co/krrmzwobDK', 'display_url': 'pic.twitter.com/krrmzwobDK', 'expanded_url': 'https://twitter.com/beartai/status/1100302707875753984/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'small': {'w': 680, 'h': 381, 're
# ...

# %%
class StreamListener(tweepy.StreamListener):

    def on_status(self, status):
        print(status.text)
        
    def on_error(self, status_code):
        if status_code == 420:
            return False

stream_listener = StreamListener()
stream = tweepy.Stream(auth=api.auth, listener=stream_listener)
stream.filter(track=["google"],languages=["en"])
# Out:
# Soros cost me thousands of pounds &amp; sleepless nights back in the '90's with his assault on the £.
# Setting up to ma… https://t.co/J1IqwKKQAj
# RT @sososwj: Have y’all seen the Google animation for Steve Irwin? 😢💚 https://t.co/a7LkLsCCah
# ▶REAL -MOTION(1/3 Quality)- https://t.co/hmQphXYAlS https://t.co/qWrnFQUT7F https://t.co/gIwc9CPZEP #music #musik #japan #INFORMATION
# @nicedice777 I SPENT 15 MINUTES ON GOOGLE LOOKING FOR ONE AND YOU'RE RIGHT SJDNKDNDDN https://t.co/7WLl6XYl3q
# RT @KKpower7: ICYMI: ”She is NOT a U.S. citizen &amp;  will NOT be admitted into the United States. She does NOT have any legal basis, no valid…
# @brianst01 Thanks for reaching us. What is the model of the device? Please try these steps: Settings&gt; Apps and noti… https://t.co/a35WCeCEmU
# RT @OntologyNetwork: You can now develop Ontology smart contracts on Google Cloud, AWS, and Azure https://t.co/5FeRqc0kES $ONT $ONG
# ...

# %%
keyword = '(thai OR thais OR thailand ) AND (election OR elections )'
# keyword = 'twitter'
for status in tweepy.Cursor(api.search, q=keyword , count=100, lang='en').items(100):
        print(status.text) 
        print("__________")
# Out:
# RT @patpichatan: Today marks exactly one month until Thailand holds the first election in nearly eight years and the first since the 2014 m…
# __________
# RT @TostevinM: The hashtag “#SaveThanathorn” was trending on Twitter in Thailand and hundreds of young people turned out for a Thanathorn r…
# __________
# RT @LocalOrgInfo: @KhaosodEnglish how are we supposed to take "Khaosod" seriously?
#
# 1. it is run by the family of a candidate (Thanathorn…
# __________
# @KhaosodEnglish how are we supposed to take "Khaosod" seriously?
#
# 1. it is run by the family of a candidate (Thana… https://t.co/uq4yigbKjW
# __________
# Join us on February 28th for a webinar on Thailand's upcoming elections, where we will explore likely election outc… https://t.co/TqTAstxPtl
# __________
# Join us on February 28th for a webinar on Thailand's upcoming elections, where we will explore likely election outc… https://t.co/rl9ZGiHQSi
# __________
# ...

# %%
stream.filter(follow=["2211149702"])
# Out:
# ♪ #nowplaying Let S Just Bash! - Jowee Omicil (Let S Bash! - 2017) https://t.co/bnbNq7U2Wp https://t.co/YmNpQQO0CU
# ♪ #nowplaying Father and Mother - Thabang Tabane (Matjale - 2018) https://t.co/bnbNq7U2Wp https://t.co/NohT8LRZvz
# ♪ #nowplaying Reves Perdus - Chlorine Free (Free Speech - 2017) https://t.co/bnbNq7U2Wp https://t.co/28fo9SYJYF
# ♪ #nowplaying Oiseau de Nuit - O (Olivier Marguerit) (A Terre - 2018) https://t.co/bnbNq7U2Wp https://t.co/uiuK4cYela
# ♪ #nowplaying Seventeen - Sharon Van Etten (Remind Me Tomorrow - 2019) https://t.co/bnbNq7U2Wp https://t.co/4M4xtK4o5E
# ♪ #nowplaying Preludes Livre I L 125 (117) : 6. Des Pas Sur la Neige - Marina Baranova (Marina Baranova : Unfolding… https://t.co/DRzX6a0o71
# ♪ #nowplaying Gesse - Ukandanz (Yeketelale - 2018) https://t.co/bnbNq7U2Wp https://t.co/TftmGuP6ws

# %%
tweets_filename = 'saveTT.txt'
tweets_file = open(tweets_filename, "r",encoding='utf-8')

for line in tweets_file:
    try:
        # Read in one line of the file, convert it into a json object 
        tweet = json.loads(line.strip())
        if 'text' in tweet: # only messages contains 'text' field is a tweet
            print(tweet['id']) # This is the tweet's id
            print(tweet['created_at']) # when the tweet posted
            print(tweet['text']) # content of the tweet
                        
            print(tweet['user']['id']) # id of the user who posted the tweet
            print(tweet['user']['name']) # name of the user, e.g. "Wei Xu"
            print(tweet['user']['screen_name']) # name of the user account, e.g. "cocoweixu"

            hashtags = []
            for hashtag in tweet['entities']['hashtags']:
                hashtags.append(hashtag['text'])
            print(hashtags)

    except:
        # read in a line is not in JSON format (sometimes error occured)
        continue

# %%
# print(json.dumps(sfo_trends, indent=4))
# Out:
# [
#     {
#         "trends": [
#             {
#                 "name": "Jeff Adachi",
#                 "url": "http://twitter.com/search?q=%22Jeff+Adachi%22",
#                 "promoted_content": null,
#                 "query": "%22Jeff+Adachi%22",
#                 "tweet_volume": null
#             },
#             {
#                 "name": "Feinstein",
#                 "url": "http://twitter.com/search?q=Feinstein",
#                 "promoted_content": null,
#                 "query": "Feinstein",
#                 "tweet_volume": 195140
#             },
#             {
#                 "name": "Robert Kraft",
#                 "url": "http://twitter.com/search?q=%22Robert+Kraft%22",
#                 "promoted_content": null,
#                 "query": "%22Robert+Kraft%22",
#                 "tweet_volume": 483447
#             },
#             {
#                 "name": "Green New Deal",
#                 "url": "http://twitter.com/search?q=%22Green+New+Deal%22",
# ...
