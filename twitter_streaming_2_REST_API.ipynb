# %%
try:
    import json
except ImportError:
    import simplejson as json
import tweepy
ACCESS_TOKEN = #your key
ACCESS_SECRET = #your key
CONSUMER_KEY = #your key
CONSUMER_SECRET = #your key
auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)

# %%
# keyword = 'ไทย'
# i = 0
# for status in tweepy.Cursor(api.search, q=keyword , count=10, lang='th').items(10):
#     i = i+1
#     print(i)
#     print(status.text)
#     print("\n")
#     print(status._json)
#     print("\n\n__________________________________________________\n\n")

#     with open('status._json.txt', 'a',encoding='utf-8') as outfile:  
#         json.dump(status._json, outfile,ensure_ascii=False)

# %%
keyword = 'ไทย'
for status in tweepy.Cursor(api.search, q=keyword , count=10, lang='th').items(10):
    with open('twitter_data.txt', 'a',encoding='utf-8') as outfile:  
        json.dump(status._json, outfile,ensure_ascii=False)

# %%
from pymongo import MongoClient
client = MongoClient()
db     = client.tt_database
tt_collection = db.tt_collection
f = open('twitter_data.txt',encoding='utf-8')
text = f.read()
doc = {
"file_name": 'twitter_data.txt',
"contents" : text }
tt_collection.insert(doc)
# Out:
# C:\Users\Asus\myConda\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: DeprecationWarning: insert is deprecated. Use insert_one or insert_many instead.
#   # Remove the CWD from sys.path while we load stuff.
# ObjectId('5c74030ad81e4529c887cce1')

# %%
for x in tt_collection.find():
    print(x) 
    print("\n\n\n\n\n______________________________________________________________________")
# Out:
# {'_id': ObjectId('5c7401d0d81e4529c887ccdf'), 'file_name': 'status._json.txt', 'contents': '{"created_at": "Mon Feb 25 13:21:20 +0000 2019", "id": 1100022938172964864, "id_str": "1100022938172964864", "text": "RT @TwelVeks: ภาษาไทยวันละคำกับไอค่อน5555555 #welcomeIKONtoThaiGalaxy #10isComingXiKON https://t.co/AfvnJ9VSCD", "truncated": false, "entities": {"hashtags": [{"text": "welcomeIKONtoThaiGalaxy", "indices": [45, 69]}, {"text": "10isComingXiKON", "indices": [70, 86]}], "symbols": [], "user_mentions": [{"screen_name": "TwelVeks", "name": "𝙏𝙪𝙣𝙚𝙟𝙪𝙣", "id": 788649002669486080, "id_str": "788649002669486080", "indices": [3, 12]}], "urls": [], "media": [{"id": 1100006564449071105, "id_str": "1100006564449071105", "indices": [87, 110], "media_url": "http://pbs.twimg.com/ext_tw_video_thumb/1100006564449071105/pu/img/F7y9jz9ZCvGkHwm0.jpg", "media_url_https": "https://pbs.twimg.com/ext_tw_video_thumb/1100006564449071105/pu/img/F7y9jz9ZCvGkHwm0.jpg", "url": "https://t.co/AfvnJ9VSCD", "displ
# ...

# %%
import json
s = '{"success": "true", "status": 200, "message": "Hello"}'
d = json.loads(s)
print (d["success"], d["status"])
# Out:
# true 200

# %%
import json

with open('t.txt',encoding='utf-8') as json_file:  
    data = json.load(json_file,encoding='utf-8')
